# %% [markdown]
# # Spoon Estuary SCHISM-AED results gallery
#
# **Prepared by Dongfang Liu**
# Current status: plotting benchmark; strict river open-boundary correction is still required.

# %% [markdown]
# ## 1. Boundary audit
#
# The lower/southern end is the river boundary and the upper/northern end is the ocean boundary. The current SCHISM case injects river flow into element 1 rather than using the corresponding five-node open boundary.
#
# ![Boundary audit](../boundary_audit/boundary_audit_map.png)

# %% [markdown]
# ## 2. Water-surface elevation
#
# ![Water surface elevation](../figures/water_surface_elevation.png)

# %% [markdown]
# ## 3. Oxygen with velocity vectors
#
# ![Oxygen and velocity](../figures/oxygen_velocity.png)

# %% [markdown]
# ## 4. Oxygen, total nitrogen and gross primary production
#
# ![Oxygen TN GPP](../figures/oxygen_tn_gpp.png)

# %% [markdown]
# ## 5. Surface, near-seabed and depth-averaged fields
#
# ![Velocity TSS TP](../figures/velocity_tss_tp_3x3.png)

# %% [markdown]
# ## 6. Next comparison products
#
# - Corrected river open-boundary case
# - Matched six-day TUFLOW/SCHISM timestamps
# - Common colour limits and physical depth bands
# - TN, TP, TSS, oxygen, chlorophyll-a, turbidity, GPP and light
# - Cross-section flux and domain mass-balance diagnostics
